# %%
# importando o pandas
import pandas as pd

# %%
# ler o arquivo em csv atráves de dataframe, definindo o separador e o encoding
df = pd.read_csv("Dados aula 1.csv", encoding = "UTF-8", sep = ';')

# %%
# exibe os 5 primeiros registros e o cabeçalho
df.head()
# Out:
#    AddressID          AddressLine1 AddressLine2     City  StateProvinceID  \
# 0          1         1970 Napa Ct.          NaN  Bothell               79
# 1          2    9833 Mt. Dias Blv.          NaN  Bothell               79
# 2          3  7484 Roundtree Drive          NaN  Bothell               79
# 3          4      9539 Glenside Dr          NaN  Bothell               79
# 4          5         1226 Shoe St.          NaN  Bothell               79
#
#   PostalCode                                 SpatialLocation  \
# 0      98011  0xE6100000010CAE8BFC28BCE4474067A89189898A5EC0
# 1      98011  0xE6100000010CD6FA851AE6D74740BC262A0A03905EC0
# 2      98011  0xE6100000010C18E304C4ADE14740DA930C7893915EC0
# 3      98011  0xE6100000010C813A0D5F9FDE474011A5C28A7C955EC0
# 4      98011  0xE6100000010C61C64D8ABBD94740C460EA3FD8855EC0
#
#                                 rowguid             ModifiedDate
# 0  9AADCB0D-36CF-483F-84D8-585C2D4EC6E9  2007-12-04 00:00:00.000
# ...

# %%
# define quais colunas voce quer ver
df = pd.read_csv("Dados aula 1.csv", encoding = "UTF-8", sep = ';', usecols=["City", "PostalCode"])

# %%
df

# %%
# define o numero de linhas a ser exibido
df = pd.read_csv("Dados aula 1.csv", encoding = "UTF-8", sep = ';', nrows = 200)

# %%
# Out:
#                   City PostalCode
# 0              Bothell      98011
# 1              Bothell      98011
# 2              Bothell      98011
# 3              Bothell      98011
# 4              Bothell      98011
# 5              Bothell      98011
# 6              Bothell      98011
# 7              Bothell      98011
# 8              Bothell      98011
# 9              Bothell      98011
# 10             Bothell      98011
# 11             Bothell      98011
# 12             Bothell      98011
# 13             Bothell      98011
# 14             Bothell      98011
# 15             Bothell      98011
# 16             Bothell      98011
# 17             Bothell      98011
# 18             Bothell      98011
# 19             Bothell      98011
# 20             Bothell      98011
# 21            Portland      97205
# 22             Seattle      98104
# 23              Duluth      55802
# 24              Dallas      75201
# 25       San Francisco      94109
# ...
